# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
import torch
import random
from torch import nn, optim
from torch.autograd.variable import Variable
import logging as log
from tensorboardX import SummaryWriter
from torchvision import transforms, datasets
BATCH_SIZE = 100
DATASET = 1500

# %%
np.random.seed(0)
random.seed(0)
torch.manual_seed(0)
torch.cuda.manual_seed(0)
torch.cuda.manual_seed_all(0)
torch.backends.cudnn.enabled = False
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True

# %% [markdown]
# # DATASET

# %%
class GaussianDataset(torch.utils.data.Dataset):
    def __init__(self,ids,labels):
        self.ids = ids
        self.labels = labels
    
    def __len__(self):
        return len(self.ids)
    
    def __getitem__(self,index):
        Id = self.ids[index]
        X = torch.load('data/' + str(Id)+'.pt')
        y = self.labels[Id]
        
        return X,y

# %%
ids = np.arange(1,DATASET + 1,1)
labels = np.full(DATASET,1) #simply labels
labels = dict([(x,y) for x,y in zip(ids,labels)]) # id to label mapping
training = GaussianDataset(ids,labels)

# %%
training_gen = torch.utils.data.DataLoader(training, batch_size=BATCH_SIZE, worker_init_fn=np.random.seed(0), shuffle=True, num_workers=0)
num_batches = len(training_gen)

# %%
num_batches
# Out:
# 15

# %% [markdown]
# # NETWORKS

# %%
class Discriminator(torch.nn.Module):
    '''
    Single hidden layer discriminator network
    '''
    def __init__(self):
        super(Discriminator,self).__init__()
        n_features = 2
        n_hidden1 = 10
        n_out = 1
        
        self.hidden = nn.Sequential(nn.Linear(n_features,n_hidden1),nn.LeakyReLU(0.2),nn.Dropout(0.3))
        self.out = nn.Sequential(nn.Linear(n_hidden1,n_out),nn.Sigmoid())
        
    def forward(self,x):
        x = self.hidden(x)
        x = self.out(x)
        return x

# %%
class Generator(torch.nn.Module):
    '''
    Single hidden layer generator network
    '''
    def __init__(self):
        super(Generator,self).__init__()
        n_features = 2
        n_hidden1 = 10
        n_hidden2 = 10
        n_out = 2
        
        self.hidden1 = nn.Sequential(nn.Linear(n_features,n_hidden1),nn.LeakyReLU(0.2))
        self.hidden2 = nn.Sequential(nn.Linear(n_hidden1,n_hidden2),nn.LeakyReLU(0.2))
        self.out = nn.Sequential(nn.Linear(n_hidden2,n_out),nn.Sigmoid())
        
    def forward(self,x):
        x = self.hidden1(x)
        x = self.hidden2(x)
        x = self.out(x)
        return x

# %%
disc = Discriminator()
disc.load_state_dict(torch.load('models/disc_initial.pt'))
gen = Generator()
gen.load_state_dict(torch.load('models/gen_initial.pt'))

if torch.cuda.is_available():
    disc.cuda()
    gen.cuda()

# %%
torch.save(gen.state_dict(),'models/gen_initial.pt')
torch.save(disc.state_dict(),'models/disc_initial.pt')

# %% [markdown]
# # Optimizer

# %%
d_opt = optim.Adam(disc.parameters(), lr = 0.0002)
g_opt = optim.Adam(gen.parameters(), lr = 0.0002)

loss = nn.BCELoss()

# %% [markdown]
# # CREATING LABELS FOR TRAINING

# %%
def real_data_target(size):
    o = torch.ones(size,1,dtype = torch.float32,requires_grad=False)
    if torch.cuda.is_available():
        return o.cuda()
    return o

def fake_data_target(size):
    z = torch.zeros(size,1,dtype = torch.float32, requires_grad=False)
    if torch.cuda.is_available():
        return z.cuda()
    return z

# %%
def noise(size):
    n =  torch.randn(size,2,dtype = torch.float32,requires_grad=False)
    if torch.cuda.is_available(): return n.cuda()
    return n

# %% [markdown]
# # TRAINING

# %%
def train_d(optimizer, real_data, fake_data):
    #set optimizer gradients to zero to store fresh gradients
    optimizer.zero_grad()
    
    prediction_real = disc(real_data.float())
    error_real = loss(prediction_real, real_data_target(real_data.size(0)))
    
    prediction_fake = disc(fake_data)    
    error_fake = loss(prediction_fake, fake_data_target(fake_data.size(0)))
    
    total_error = (error_real + error_fake)/2
    total_error.backward()
    optimizer.step() #update weights
    
    return (error_real + error_fake)/2, prediction_real, prediction_fake    

def train_g(optimizer, fake_data):
    optimizer.zero_grad()
    
    prediction = disc(fake_data.float())
    error = loss(prediction, real_data_target(prediction.size(0)))
    error.backward()
    optimizer.step()
    return error

# %%
#number of steps to train discriminator
EPOCHS = 1000
BATCHES = DATASET/BATCH_SIZE

# %%
d_errors = []
g_errors = []

# %%
writer = SummaryWriter()

# %%
for epoch in range(EPOCHS):
    g_err_avg = 0
    d_err_avg = 0
    for n_batch,(real_batch,_) in enumerate(training_gen):
        #generate noise data
        noise_data = noise(real_batch.size(0)).float()
        fake_data = gen(noise_data).float()
        
        #Train discriminator
        real_data = real_batch
        if torch.cuda.is_available(): 
            real_data = real_data.cuda()
        
        d_error, d_predr, d_predf = train_d(d_opt,real_data,fake_data.detach())
        d_err_avg+=d_error
        
        #Train generator
        g_error = train_g(g_opt,fake_data)
        g_err_avg+=g_error
        
    d_errors.append(d_err_avg/BATCHES)
    g_errors.append(g_err_avg/BATCHES)
    writer.add_scalar('epochdata',d_err_avg/BATCHES,epoch)
    if epoch%20==0:
        print("Epoch no : {} Discriminator error: {}   Generator error: {}".format(epoch,d_err_avg/BATCHES,g_err_avg/BATCHES))
writer.close()
# Out:
# Epoch no : 0 Discriminator error: 0.6958155632019043   Generator error: 0.7917081117630005
# Epoch no : 20 Discriminator error: 0.6853177547454834   Generator error: 0.7316802144050598
# Epoch no : 40 Discriminator error: 0.6783744096755981   Generator error: 0.7051694393157959
# Epoch no : 60 Discriminator error: 0.682620644569397   Generator error: 0.692887544631958
# Epoch no : 80 Discriminator error: 0.6947880387306213   Generator error: 0.7014600038528442
# Epoch no : 100 Discriminator error: 0.6621817350387573   Generator error: 0.7791470885276794
# Epoch no : 120 Discriminator error: 0.69133460521698   Generator error: 0.6955791115760803
# Epoch no : 140 Discriminator error: 0.7192559838294983   Generator error: 0.6422409415245056
# Epoch no : 160 Discriminator error: 0.6849681735038757   Generator error: 0.688544511795044
# Epoch no : 180 Discriminator error: 0.6680753231048584   Generator error: 0.7034361362457275
# Epoch no : 200 Discriminator error: 0.7128668427467346   Generator error: 0.6728826761245728
# Epoch no : 220 Discriminator error: 0.7002472877502441   Generator error: 0.7199925184249878
# Epoch no : 240 Discriminator error: 0.6568169593811035   Generator error: 0.7944908738136292
# Epoch no : 260 Discriminator error: 0.6954378485679626   Generator error: 0.69789057970047
# Epoch no : 280 Discriminator error: 0.7079981565475464   Generator error: 0.6565337181091309
# Epoch no : 300 Discriminator error: 0.691592812538147   Generator error: 0.6860025525093079
# Epoch no : 320 Discriminator error: 0.6898868680000305   Generator error: 0.6932136416435242
# Epoch no : 340 Discriminator error: 0.7022231221199036   Generator error: 0.6882592439651489
# Epoch no : 360 Discriminator error: 0.6933677792549133   Generator error: 0.7061594724655151
# Epoch no : 380 Discriminator error: 0.6854294538497925   Generator error: 0.7091896533966064
# Epoch no : 400 Discriminator error: 0.6944981217384338   Generator error: 0.692953884601593
# Epoch no : 420 Discriminator error: 0.6963990926742554   Generator error: 0.6910465955734253
# Epoch no : 440 Discriminator error: 0.6991394758224487   Generator error: 0.6884481310844421
# Epoch no : 460 Discriminator error: 0.6930534243583679   Generator error: 0.7011906504631042
# Epoch no : 480 Discriminator error: 0.690366804599762   Generator error: 0.6983097791671753
# Epoch no : 500 Discriminator error: 0.6924954056739807   Generator error: 0.6945531368255615
# Epoch no : 520 Discriminator error: 0.6971235871315002   Generator error: 0.6891978979110718
# Epoch no : 540 Discriminator error: 0.6932328939437866   Generator error: 0.6896596550941467
# Epoch no : 560 Discriminator error: 0.6911816596984863   Generator error: 0.6952958106994629
# Epoch no : 580 Discriminator error: 0.6944059133529663   Generator error: 0.6948540806770325
# Epoch no : 600 Discriminator error: 0.6957763433456421   Generator error: 0.6936226487159729
# Epoch no : 620 Discriminator error: 0.6903713345527649   Generator error: 0.6969568133354187
# Epoch no : 640 Discriminator error: 0.6923038959503174   Generator error: 0.694987952709198
# Epoch no : 660 Discriminator error: 0.6958104372024536   Generator error: 0.6900880336761475
# Epoch no : 680 Discriminator error: 0.692367434501648   Generator error: 0.6945168375968933
# Epoch no : 700 Discriminator error: 0.6935561299324036   Generator error: 0.6947731971740723
# Epoch no : 720 Discriminator error: 0.6943929195404053   Generator error: 0.6940044164657593
# Epoch no : 740 Discriminator error: 0.690510630607605   Generator error: 0.6968282461166382
# Epoch no : 760 Discriminator error: 0.6941118240356445   Generator error: 0.693068265914917
# Epoch no : 780 Discriminator error: 0.6920681595802307   Generator error: 0.6942527890205383
# Epoch no : 800 Discriminator error: 0.692747175693512   Generator error: 0.6934084892272949
# Epoch no : 820 Discriminator error: 0.6933425664901733   Generator error: 0.6946730017662048
# Epoch no : 840 Discriminator error: 0.6922568082809448   Generator error: 0.6946445107460022
# Epoch no : 860 Discriminator error: 0.6928970813751221   Generator error: 0.6935413479804993
# Epoch no : 880 Discriminator error: 0.6929854154586792   Generator error: 0.6948102712631226
# Epoch no : 900 Discriminator error: 0.6933853030204773   Generator error: 0.6937184929847717
# Epoch no : 920 Discriminator error: 0.6924946308135986   Generator error: 0.694145917892456
# Epoch no : 940 Discriminator error: 0.693632960319519   Generator error: 0.6934226155281067
# Epoch no : 960 Discriminator error: 0.6924108266830444   Generator error: 0.6944588422775269
# Epoch no : 980 Discriminator error: 0.6936379075050354   Generator error: 0.693200409412384

# %% [markdown]
# # PLOTTING

# %%
plt.rcParams.update({'font.size': 14})

# %%
#graph comparison
fig,ax = plt.subplots(figsize = (20,6))
ax.plot(d_errors, label = "Discriminator")
ax.plot(g_errors, label = "Generator")
ax.set_xlabel('Epochs')
ax.set_ylabel('Logloss error')
# ax.set_title('Trimodal data with mean (1,1), (6,6) and (11,11) and stddev (0.5,0.5), (0.6,0.6),(1,1)')
ax.legend()
ax.minorticks_on()
ax.grid(which='major', linestyle='solid', linewidth='0.25', color='gray')
ax.grid(which='minor', linestyle='solid', linewidth='0.25', color='gray')
ax.set_xlim(left=0)
ax.set_ylim(top=0.85,bottom=0.625)
plt.show()
fig.savefig('plotvgan',dpi=600)

# %%
def comparedata(pp):
    pp = [list(np.array(x)) for x in pp]
    pp = torch.tensor(pp)
    pp = np.array(pp.detach().cpu())
    fig, ax = plt.subplots(figsize = (10,10))
    plt.scatter(pp[:,0],pp[:,1],color = 'green')
    
    #gen data
    b = np.array(gen(noise(1000)).detach().cpu())
    
    #compare
    plt.scatter(b[:,0],b[:,1], color = 'orange')
#     plt.title('Trimodal data with mean (1,1), (6,6) and (11,11) and stddev (0.5,0.5), (0.6,0.6),(1,1)')
    plt.show()

# %%
pp = []
for i in range(DATASET):
    pp.append(torch.load('data/'+ str(i+1) + '.pt'))
comparedata(pp)

# %%
torch.save(disc.state_dict(),'models/model4/disc.pt')
torch.save(gen.state_dict(),'models/model4/gen.pt')
